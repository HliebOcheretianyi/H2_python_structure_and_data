# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, make_scorer
from xgboost import XGBClassifier
import pickle
import joblib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../../data/all_data_preprocessed/all_merged_tfidf.parquet')

# %%
X = df.drop(columns=[
    'event_all_region','alarms_in_regions', 'event_1h_ago',
    'event_2h_ago'])
y = df['event_all_region']

# %%
#X.rename(columns={"event_1h_ago": "status"}, inplace=True)

# %%
tscv = TimeSeriesSplit(n_splits=5)
splits = list(tscv.split(X))
train_idx, test_idx = splits[-1]
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
neg_pos_ratio = sum(y_train == 0) / sum(y_train == 1)
neg_pos_ratio
# Out:
# 2.78725174626114

# %%
param_grid = {
    'n_estimators': [100, 150],
    'max_depth': [6, 8],
    'learning_rate': [0.2, 0.4],
    'subsample': [0.6, 0.8],
    'colsample_bytree': [0.6, 0.8],
    'min_child_weight': [1, 3, 5],
    'gamma': [0.5],
}

# %%
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='aucpr',
    random_state=42,
    tree_method='hist',
    subsample=0.8,
    n_estimators=150,
    min_child_weight=3,
    max_depth=6,
    learning_rate=0.4,
    gamma=0.5,
    colsample_bytree=0.8,
    n_jobs=-1
)

# %%
# f1_scorer = make_scorer(f1_score)

# %%
# random_search = RandomizedSearchCV(
#     estimator=xgb_model,
#     param_distributions=param_grid,
#     n_iter=6,
#     scoring=f1_scorer,
#     cv=tscv,
#     verbose=2,
#     random_state=42,
#     n_jobs=1
# )

# %%
# random_search.fit(X_train_scaled, y_train)

# %%
# print(random_search.best_params_)
# print(random_search.best_score_)
# {'subsample': 0.8, 'n_estimators': 150, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.4, 'gamma': 0.5, 'colsample_bytree': 0.8}
# 0.7994637983532699

# %%
# xgb_model = XGBClassifier(
#     **random_search.best_params_,
#     objective='binary:logistic',
#     random_state=42,
#     eval_metric='aucpr',
#     device='cpu',
#     n_jobs=-1
# )

# %%
xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='aucpr', feature_types=None,
#               feature_weights=None, gamma=0.5, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.4, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=3, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=150,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = xgb_model.predict(X_test_scaled)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9034169750231268

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[83076,  2678],
#        [ 7345, 10677]])

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6805621952385505

# %%
print(
classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94     85754
#          1.0       0.80      0.59      0.68     18022
#
#     accuracy                           0.90    103776
#    macro avg       0.86      0.78      0.81    103776
# weighted avg       0.90      0.90      0.90    103776

# %%
importance = xgb_model.feature_importances_
feature_names = X_train.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})

# %%
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
top_20_features = importance_df.head(20)
print(top_20_features)
# Out:
#                    Feature  Importance
# 1037  event_lastDay_region    0.029217
# 223                    186    0.007774
# 318                    281    0.004956
# 762                    725    0.004906
# 671                    634    0.004813
# 391                    354    0.004737
# 834                    797    0.004607
# 325                    288    0.004477
# 464                    427    0.004364
# 873                    836    0.004229
# 780                    743    0.004115
# 359                    322    0.003960
# 580                    543    0.003690
# 640                    603    0.003590
# 734                    697    0.003589
# 618                    581    0.003487
# 761                    724    0.003296
# 216                    179    0.003279
# 579                    542    0.003275
# 1        day_datetimeEpoch    0.003183

# %%
with open('../../src/our_models/3__Xgboost__v2.pkl', 'wb') as f:
    pickle.dump(xgb_model, f)

# %%
X_train
# Out:
#         region_id  day_datetimeEpoch  day_tempmax  day_tempmin  day_temp  \
# 0             1.0       1.645740e+09          6.0         -1.0       2.6
# 1             1.0       1.645740e+09          6.0         -1.0       2.6
# 2             1.0       1.645740e+09          6.0         -1.0       2.6
# 3             1.0       1.645740e+09          6.0         -1.0       2.6
# 4             1.0       1.645740e+09          6.0         -1.0       2.6
# ...           ...                ...          ...          ...       ...
# 518875       21.0       1.740780e+09          4.9         -6.9      -0.9
# 518876       21.0       1.740780e+09          4.9         -6.9      -0.9
# 518877       21.0       1.740780e+09          4.9         -6.9      -0.9
# 518878       21.0       1.740780e+09          4.9         -6.9      -0.9
# 518879       21.0       1.740780e+09          4.9         -6.9      -0.9
#
#         day_dew  day_humidity  day_precip  day_precipcover  \
# 0          -0.4     81.900002         0.0              0.0
# 1          -0.4     81.900002         0.0              0.0
# 2          -0.4     81.900002         0.0              0.0
# 3          -0.4     81.900002         0.0              0.0
# 4          -0.4     81.900002         0.0              0.0
# ...         ...           ...         ...              ...
# 518875     -5.9     71.300003         0.0              0.0
# 518876     -5.9     71.300003         0.0              0.0
# 518877     -5.9     71.300003         0.0              0.0
# 518878     -5.9     71.300003         0.0              0.0
# 518879     -5.9     71.300003         0.0              0.0
#
#         day_solarradiation  ...    993    994    995    996    997    998  \
# 0               126.199997  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 1               126.199997  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 2               126.199997  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 3               126.199997  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 4               126.199997  ...  0.527  0.533  0.503  0.519  0.501  0.457
# ...                    ...  ...    ...    ...    ...    ...    ...    ...
# 518875          140.100006  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 518876          140.100006  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 518877          140.100006  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 518878          140.100006  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 518879          140.100006  ...  0.659  0.560  0.639  0.610  0.601  0.572
#
#           999  event_lastDay_region  ru_holiday  ua_holiday
# 0       0.617                   0.0         0.0         0.0
# 1       0.617                   0.0         0.0         0.0
# 2       0.617                   2.0         0.0         0.0
# 3       0.617                   2.0         0.0         0.0
# 4       0.617                   2.0         0.0         0.0
# ...       ...                   ...         ...         ...
# 518875  0.756                  10.0         0.0         0.0
# 518876  0.756                  10.0         0.0         0.0
# 518877  0.756                  10.0         0.0         0.0
# 518878  0.756                  10.0         0.0         0.0
# 518879  0.756                  10.0         0.0         0.0
#
# [518880 rows x 1040 columns]

# %%
X
# Out:
#         region_id  day_datetimeEpoch  day_tempmax  day_tempmin  day_temp  \
# 0               1         1645740000          6.0         -1.0       2.6
# 1               1         1645740000          6.0         -1.0       2.6
# 2               1         1645740000          6.0         -1.0       2.6
# 3               1         1645740000          6.0         -1.0       2.6
# 4               1         1645740000          6.0         -1.0       2.6
# ...           ...                ...          ...          ...       ...
# 622651         25         1740780000          0.6         -2.4      -0.7
# 622652         25         1740780000          0.6         -2.4      -0.7
# 622653         25         1740780000          0.6         -2.4      -0.7
# 622654         25         1740780000          0.6         -2.4      -0.7
# 622655         25         1740780000          0.6         -2.4      -0.7
#
#         day_dew  day_humidity  day_precip  day_precipcover  \
# 0          -0.4          81.9         0.0             0.00
# 1          -0.4          81.9         0.0             0.00
# 2          -0.4          81.9         0.0             0.00
# 3          -0.4          81.9         0.0             0.00
# 4          -0.4          81.9         0.0             0.00
# ...         ...           ...         ...              ...
# 622651     -2.8          86.3         2.0             4.17
# 622652     -2.8          86.3         2.0             4.17
# 622653     -2.8          86.3         2.0             4.17
# 622654     -2.8          86.3         2.0             4.17
# 622655     -2.8          86.3         2.0             4.17
#
#         day_solarradiation  ...    993    994    995    996    997    998  \
# 0                    126.2  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 1                    126.2  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 2                    126.2  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 3                    126.2  ...  0.527  0.533  0.503  0.519  0.501  0.457
# 4                    126.2  ...  0.527  0.533  0.503  0.519  0.501  0.457
# ...                    ...  ...    ...    ...    ...    ...    ...    ...
# 622651                41.0  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 622652                41.0  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 622653                41.0  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 622654                41.0  ...  0.659  0.560  0.639  0.610  0.601  0.572
# 622655                41.0  ...  0.659  0.560  0.639  0.610  0.601  0.572
#
#           999  event_lastDay_region  ru_holiday  ua_holiday
# 0       0.617                     0           0           0
# 1       0.617                     0           0           0
# 2       0.617                     2           0           0
# 3       0.617                     2           0           0
# 4       0.617                     2           0           0
# ...       ...                   ...         ...         ...
# 622651  0.756                     6           0           0
# 622652  0.756                     6           0           0
# 622653  0.756                     6           0           0
# 622654  0.756                     6           0           0
# 622655  0.756                     6           0           0
#
# [622656 rows x 1040 columns]

# %%
joblib.dump(scaler, '../../src/our_models/scaler_v2.pkl')
# Out:
# ['../../src/our_models/scaler_v2.pkl']
