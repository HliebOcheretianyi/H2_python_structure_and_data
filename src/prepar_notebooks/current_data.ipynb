# %%
import os
import sys
import pandas as pd
from datetime import date
from src.preparations import weather_scrap as w
from src.preparations import alerts_in_ua as a
import holidays

# %% [markdown]
# ### Merging regions and weather

# %%
df_regions = pd.read_csv(f"../../data/regions.csv")

# %%
df_regions.head(5)
# Out:
#              region center_city_ua center_city_en        region_alt  region_id
# 0           АР Крим    Сімферополь     Simferopol              Крим          1
# 1         Вінницька        Вінниця      Vinnytsia        Вінниччина          2
# 2         Волинська          Луцьк          Lutsk            Волинь          3
# 3  Дніпропетровська         Дніпро         Dnipro  Дніпропетровщина          4
# 4          Донецька        Донецьк        Donetsk         Донеччина          5

# %%
df_regions["region"].unique()
# Out:
# array(['АР Крим', 'Вінницька', 'Волинська', 'Дніпропетровська',
#        'Донецька', 'Житомирська', 'Закарпатська', 'Запорізька',
#        'Івано-Франківська', 'Київська', 'Кіровоградська', 'Луганська',
#        'Львівська', 'Миколаївська', 'Одеська', 'Полтавська', 'Рівненська',
#        'Сумська', 'Тернопільська', 'Харківська', 'Херсонська',
#        'Хмельницька', 'Черкаська', 'Чернівецька', 'Чернігівська'],
#       dtype=object)

# %%
df_regions["region"] = df_regions["region"].apply(lambda x: x + " обл.")

# %%
weather_regions = [
    "Vinnytsia, Ukraine",
    "Lutsk, Ukraine",
    "Dnipro, Ukraine",
    "Donetsk, Ukraine",
    "Zhytomyr, Ukraine",
    "Uzhhorod, Ukraine",
    "Zaporizhia, Ukraine",
    "Ivano-Frankivsk, Ukraine",
    "Kyiv, Ukraine",
    "Kropyvnytskyi, Ukraine",
    "Lviv, Ukraine",
    "Mykolaiv, Ukraine",
    "Odessa, Ukraine",
    "Poltava, Ukraine",
    "Rivne, Ukraine",
    "Sumy, Ukraine",
    "Ternopil, Ukraine",
    "Kharkiv, Ukraine",
    "Kherson, Ukraine",
    "Khmelnytskyi, Ukraine",
    "Cherkasy, Ukraine",
    "Chernivtsi, Ukraine",
    "Chernigiv, Ukraine"
]

# %%
all_data = []

for region in weather_regions:
    forecast = w.generate_forecast(region)
    
    df_region = pd.DataFrame(forecast)
    all_data.append(df_region)

df_weather = pd.concat(all_data, ignore_index=True)
df_weather.head()
# Out:
#   city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0     Вінниця, Україна   2025-05-05         1746392400         15.4
# 1     Вінниця, Україна   2025-05-06         1746478800         14.7
# 2     Вінниця, Україна   2025-05-06         1746478800         14.7
# 3     Вінниця, Україна   2025-05-06         1746478800         14.7
# 4     Вінниця, Україна   2025-05-06         1746478800         14.7
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover  \
# 0          9.7      12.2      9.2          82.2         5.5            45.83
# 1          8.3      11.2      7.8          79.9         5.3            45.83
# 2          8.3      11.2      7.8          79.9         5.3            45.83
# 3          8.3      11.2      7.8          79.9         5.3            45.83
# 4          8.3      11.2      7.8          79.9         5.3            45.83
#
#    ...  hour_snowdepth  hour_preciptype  hour_windgust hour_windspeed  \
# 0  ...             0.0           [rain]            8.3            3.6
# 1  ...             0.0           [rain]            7.9            2.9
# 2  ...             0.0             None            8.6            4.0
# 3  ...             0.0             None           14.8            6.8
# 4  ...             0.0           [rain]           19.4            9.0
#
#   hour_winddir  hour_pressure hour_visibility  hour_cloudcover  hour_uvindex  \
# 0        356.3         1013.0            24.1             98.2           0.0
# 1        358.3         1014.0            24.1             96.8           0.0
# 2          0.4         1014.0            24.1            100.0           0.0
# 3         26.0         1014.0            24.1             96.6           0.0
# 4         38.9         1013.0            13.2             90.0           0.0
#
#     hour_conditions
# 0          Overcast
# 1          Overcast
# 2          Overcast
# 3          Overcast
# 4  Partially cloudy
#
# [5 rows x 34 columns]

# %%
df_weather
# Out:
#     city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0       Вінниця, Україна   2025-05-05         1746392400         15.4
# 1       Вінниця, Україна   2025-05-06         1746478800         14.7
# 2       Вінниця, Україна   2025-05-06         1746478800         14.7
# 3       Вінниця, Україна   2025-05-06         1746478800         14.7
# 4       Вінниця, Україна   2025-05-06         1746478800         14.7
# ..                   ...          ...                ...          ...
# 547    Чернігів, Україна   2025-05-06         1746478800         12.9
# 548    Чернігів, Україна   2025-05-06         1746478800         12.9
# 549    Чернігів, Україна   2025-05-06         1746478800         12.9
# 550    Чернігів, Україна   2025-05-06         1746478800         12.9
# 551    Чернігів, Україна   2025-05-06         1746478800         12.9
#
#      day_tempmin  day_temp  day_dew  day_humidity  day_precip  \
# 0            9.7      12.2      9.2          82.2         5.5
# 1            8.3      11.2      7.8          79.9         5.3
# 2            8.3      11.2      7.8          79.9         5.3
# 3            8.3      11.2      7.8          79.9         5.3
# 4            8.3      11.2      7.8          79.9         5.3
# ..           ...       ...      ...           ...         ...
# 547          3.8       9.2      1.1          58.2         0.0
# 548          3.8       9.2      1.1          58.2         0.0
# 549          3.8       9.2      1.1          58.2         0.0
# 550          3.8       9.2      1.1          58.2         0.0
# 551          3.8       9.2      1.1          58.2         0.0
#
#      day_precipcover  ...  hour_snowdepth  hour_preciptype  hour_windgust  \
# 0              45.83  ...             0.0           [rain]            8.3
# 1              45.83  ...             0.0           [rain]            7.9
# 2              45.83  ...             0.0             None            8.6
# 3              45.83  ...             0.0             None           14.8
# 4              45.83  ...             0.0           [rain]           19.4
# ..               ...  ...             ...              ...            ...
# 547             0.00  ...             0.0             None            6.8
# 548             0.00  ...             0.0             None            9.4
# 549             0.00  ...             0.0             None            9.7
# 550             0.00  ...             0.0             None           10.4
# 551             0.00  ...             0.0             None            6.8
#
#     hour_windspeed hour_winddir  hour_pressure hour_visibility  \
# 0              3.6        356.3         1013.0            24.1
# 1              2.9        358.3         1014.0            24.1
# 2              4.0          0.4         1014.0            24.1
# 3              6.8         26.0         1014.0            24.1
# 4              9.0         38.9         1013.0            13.2
# ..             ...          ...            ...             ...
# 547            2.2        353.1         1014.0            24.1
# 548            4.7        334.3         1014.0            24.1
# 549            4.7        331.7         1014.0            24.1
# 550            3.6        327.2         1015.0            24.1
# 551            2.9        333.6         1015.0            24.1
#
#      hour_cloudcover  hour_uvindex   hour_conditions
# 0               98.2           0.0          Overcast
# 1               96.8           0.0          Overcast
# 2              100.0           0.0          Overcast
# 3               96.6           0.0          Overcast
# 4               90.0           0.0  Partially cloudy
# ..               ...           ...               ...
# 547             87.0           3.0  Partially cloudy
# 548            100.0           2.0          Overcast
# 549             97.6           0.0          Overcast
# 550             98.8           0.0          Overcast
# 551            100.0           0.0          Overcast
#
# [552 rows x 34 columns]

# %%
df_weather.columns
# Out:
# Index(['city_resolvedAddress', 'day_datetime', 'day_datetimeEpoch',
#        'day_tempmax', 'day_tempmin', 'day_temp', 'day_dew', 'day_humidity',
#        'day_precip', 'day_precipcover', 'day_solarradiation',
#        'day_solarenergy', 'day_uvindex', 'day_sunrise', 'day_sunset',
#        'day_moonphase', 'hour_datetime', 'hour_datetimeEpoch', 'hour_temp',
#        'hour_humidity', 'hour_dew', 'hour_precip', 'hour_precipprob',
#        'hour_snow', 'hour_snowdepth', 'hour_preciptype', 'hour_windgust',
#        'hour_windspeed', 'hour_winddir', 'hour_pressure', 'hour_visibility',
#        'hour_cloudcover', 'hour_uvindex', 'hour_conditions'],
#       dtype='object')

# %%
df_weather["city"] = df_weather["city_resolvedAddress"].apply(lambda x: x.split(",")[0])
df_weather["city"] = df_weather["city"].replace('Хмельницька область', "Хмельницький")

# %%
df_weather.head(5)
# Out:
#   city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0     Вінниця, Україна   2025-05-05         1746392400         15.4
# 1     Вінниця, Україна   2025-05-06         1746478800         14.7
# 2     Вінниця, Україна   2025-05-06         1746478800         14.7
# 3     Вінниця, Україна   2025-05-06         1746478800         14.7
# 4     Вінниця, Україна   2025-05-06         1746478800         14.7
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover  \
# 0          9.7      12.2      9.2          82.2         5.5            45.83
# 1          8.3      11.2      7.8          79.9         5.3            45.83
# 2          8.3      11.2      7.8          79.9         5.3            45.83
# 3          8.3      11.2      7.8          79.9         5.3            45.83
# 4          8.3      11.2      7.8          79.9         5.3            45.83
#
#    ...  hour_preciptype  hour_windgust  hour_windspeed hour_winddir  \
# 0  ...           [rain]            8.3             3.6        356.3
# 1  ...           [rain]            7.9             2.9        358.3
# 2  ...             None            8.6             4.0          0.4
# 3  ...             None           14.8             6.8         26.0
# 4  ...           [rain]           19.4             9.0         38.9
#
#   hour_pressure  hour_visibility hour_cloudcover  hour_uvindex  \
# 0        1013.0             24.1            98.2           0.0
# 1        1014.0             24.1            96.8           0.0
# 2        1014.0             24.1           100.0           0.0
# 3        1014.0             24.1            96.6           0.0
# 4        1013.0             13.2            90.0           0.0
#
#     hour_conditions     city
# 0          Overcast  Вінниця
# 1          Overcast  Вінниця
# 2          Overcast  Вінниця
# 3          Overcast  Вінниця
# 4  Partially cloudy  Вінниця
#
# [5 rows x 35 columns]

# %%
df_weather_reg = pd.merge(df_weather, df_regions, left_on="city",right_on="center_city_ua")

# %%
df_weather_reg.head(5)
# Out:
#   city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0     Вінниця, Україна   2025-05-05         1746392400         15.4
# 1     Вінниця, Україна   2025-05-06         1746478800         14.7
# 2     Вінниця, Україна   2025-05-06         1746478800         14.7
# 3     Вінниця, Україна   2025-05-06         1746478800         14.7
# 4     Вінниця, Україна   2025-05-06         1746478800         14.7
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover  \
# 0          9.7      12.2      9.2          82.2         5.5            45.83
# 1          8.3      11.2      7.8          79.9         5.3            45.83
# 2          8.3      11.2      7.8          79.9         5.3            45.83
# 3          8.3      11.2      7.8          79.9         5.3            45.83
# 4          8.3      11.2      7.8          79.9         5.3            45.83
#
#    ...  hour_visibility  hour_cloudcover  hour_uvindex   hour_conditions  \
# 0  ...             24.1             98.2           0.0          Overcast
# 1  ...             24.1             96.8           0.0          Overcast
# 2  ...             24.1            100.0           0.0          Overcast
# 3  ...             24.1             96.6           0.0          Overcast
# 4  ...             13.2             90.0           0.0  Partially cloudy
#
#       city          region center_city_ua  center_city_en  region_alt  \
# 0  Вінниця  Вінницька обл.        Вінниця       Vinnytsia  Вінниччина
# 1  Вінниця  Вінницька обл.        Вінниця       Vinnytsia  Вінниччина
# 2  Вінниця  Вінницька обл.        Вінниця       Vinnytsia  Вінниччина
# 3  Вінниця  Вінницька обл.        Вінниця       Vinnytsia  Вінниччина
# 4  Вінниця  Вінницька обл.        Вінниця       Vinnytsia  Вінниччина
#
#    region_id
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
#
# [5 rows x 40 columns]

# %%
df_weather_reg["region"] = df_weather_reg["region"].str.replace(r"\s*обл\.?", " область", regex=True)

# %%
kyiv_reg = df_weather_reg[df_weather_reg["region"] == "Київська область"].copy()
kyiv_reg["region"] = "Київ"
kyiv_reg["region_id"] = 1

df_weather_reg = pd.concat([df_weather_reg, kyiv_reg])

# %% [markdown]
# ### Merging weather, alarms and regions together

# %%
df_alarms = pd.DataFrame(a.get_alerts())
df_alarms.head()
# Out:
#                       region status
# 0  Автономна Республіка Крим      A
# 1          Волинська область      N
# 2          Вінницька область      N
# 3   Дніпропетровська область      N
# 4           Донецька область      A

# %%
df_alarms["status"] = df_alarms["status"].apply(lambda x: 1 if x == 'A' or 'P' else 0)

# %%
df_weather_reg_al = df_weather_reg.merge(df_alarms, how="left", left_on="region", right_on="region")

# %%
df_weather_reg_al
# Out:
#     city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0       Вінниця, Україна   2025-05-05         1746392400         15.4
# 1       Вінниця, Україна   2025-05-06         1746478800         14.7
# 2       Вінниця, Україна   2025-05-06         1746478800         14.7
# 3       Вінниця, Україна   2025-05-06         1746478800         14.7
# 4       Вінниця, Україна   2025-05-06         1746478800         14.7
# ..                   ...          ...                ...          ...
# 571        Київ, Україна   2025-05-06         1746478800         13.3
# 572        Київ, Україна   2025-05-06         1746478800         13.3
# 573        Київ, Україна   2025-05-06         1746478800         13.3
# 574        Київ, Україна   2025-05-06         1746478800         13.3
# 575        Київ, Україна   2025-05-06         1746478800         13.3
#
#      day_tempmin  day_temp  day_dew  day_humidity  day_precip  \
# 0            9.7      12.2      9.2          82.2         5.5
# 1            8.3      11.2      7.8          79.9         5.3
# 2            8.3      11.2      7.8          79.9         5.3
# 3            8.3      11.2      7.8          79.9         5.3
# 4            8.3      11.2      7.8          79.9         5.3
# ..           ...       ...      ...           ...         ...
# 571          7.2      10.6      3.8          63.2         0.8
# 572          7.2      10.6      3.8          63.2         0.8
# 573          7.2      10.6      3.8          63.2         0.8
# 574          7.2      10.6      3.8          63.2         0.8
# 575          7.2      10.6      3.8          63.2         0.8
#
#      day_precipcover  ...  hour_cloudcover  hour_uvindex   hour_conditions  \
# 0              45.83  ...             98.2           0.0          Overcast
# 1              45.83  ...             96.8           0.0          Overcast
# 2              45.83  ...            100.0           0.0          Overcast
# 3              45.83  ...             96.6           0.0          Overcast
# 4              45.83  ...             90.0           0.0  Partially cloudy
# ..               ...  ...              ...           ...               ...
# 571            16.67  ...            100.0           0.0    Rain, Overcast
# 572            16.67  ...            100.0           0.0    Rain, Overcast
# 573            16.67  ...             99.3           0.0    Rain, Overcast
# 574            16.67  ...             97.2           0.0    Rain, Overcast
# 575            16.67  ...             99.3           0.0    Rain, Overcast
#
#         city             region  center_city_ua center_city_en  region_alt  \
# 0    Вінниця  Вінницька область         Вінниця      Vinnytsia  Вінниччина
# 1    Вінниця  Вінницька область         Вінниця      Vinnytsia  Вінниччина
# 2    Вінниця  Вінницька область         Вінниця      Vinnytsia  Вінниччина
# 3    Вінниця  Вінницька область         Вінниця      Vinnytsia  Вінниччина
# 4    Вінниця  Вінницька область         Вінниця      Vinnytsia  Вінниччина
# ..       ...                ...             ...            ...         ...
# 571     Київ               Київ            Київ           Kyiv    Київщина
# 572     Київ               Київ            Київ           Kyiv    Київщина
# 573     Київ               Київ            Київ           Kyiv    Київщина
# 574     Київ               Київ            Київ           Kyiv    Київщина
# 575     Київ               Київ            Київ           Kyiv    Київщина
#
#      region_id  status
# 0            2       1
# 1            2       1
# 2            2       1
# 3            2       1
# 4            2       1
# ..         ...     ...
# 571          1       1
# 572          1       1
# 573          1       1
# 574          1       1
# 575          1       1
#
# [576 rows x 41 columns]

# %%
df_weather_reg_al["day_datetime"] = pd.to_datetime(df_weather_reg_al["day_datetime"])

# %% [markdown]
# ### Merging vectorized ISW to the rest

# %%
df_isw_vect = pd.read_csv("../../data/ISW_vector_tfidf.csv")

# %%
df_isw_vect.tail(10)
# Out:
#             date                                            content  \
# 1074  2025-02-22  russian offensive campaign assessment 2025 nic...
# 1075  2025-02-23  russian offensive campaign assessment 2025 nic...
# 1076  2025-02-24  russian offensive campaign assessment 2025 ang...
# 1077  2025-02-25  russian offensive campaign assessment 2025 chr...
# 1078  2025-02-26  russian offensive campaign assessment 2025 dav...
# 1079  2025-02-27  russian offensive campaign assessment 2025 chr...
# 1080  2025-02-28  russian offensive campaign assessment 2025 oli...
# 1081  2025-03-01  russian offensive campaign assessment 2025 dav...
# 1082  2025-04-21  russian offensive campaign assessment 2025 nic...
# 1083  2025-04-24  russian offensive campaign assessment 2025 chr...
#
#                                           lemma_content  \
# 1074  russian offensive campaign assessment 2025 nic...
# 1075  russian offensive campaign assessment 2025 nic...
# 1076  russian offensive campaign assessment 2025 ang...
# 1077  russian offensive campaign assessment 2025 chr...
# 1078  russian offensive campaign assessment 2025 dav...
# 1079  russian offensive campaign assessment 2025 chr...
# 1080  russian offensive campaign assessment 2025 oli...
# 1081  russian offensive campaign assessment 2025 dav...
# 1082  russian offensive campaign assessment 2025 nic...
# 1083  russian offensive campaign assessment 2025 chr...
#
#                                            stem_content  \
# 1074  russian offens campaign assess 2025 nicol wolk...
# 1075  russian offens campaign assess 2025 nicol wolk...
# 1076  russian offens campaign assess 2025 angelica e...
# 1077  russian offens campaign assess 2025 christina ...
# 1078  russian offens campaign assess 2025 davit gasp...
# 1079  russian offens campaign assess 2025 christina ...
# 1080  russian offens campaign assess 2025 olivia gib...
# 1081  russian offens campaign assess 2025 davit gasp...
# 1082  russian offens campaign assess 2025 nicol wolk...
# 1083  russian offens campaign assess 2025 christina ...
#
#                                                keywords
# 1074  0.086 0.087 0.114 0.478 0.056 0.087 0.106 0.10...
# 1075  0.064 0.065 0.171 0.082 0.055 0.042 0.065 0.08...
# 1076  0.05 0.051 0.2 0.066 0.065 0.043 0.05 0.033 0....
# 1077  0.057 0.055 0.096 0.037 0.043 0.086 0.03 0.058...
# 1078  0.087 0.088 0.057 0.088 0.108 0.121 0.118 0.08...
# 1079  0.067 0.067 0.077 0.067 0.043 0.068 0.083 0.09...
# 1080  0.067 0.067 0.178 0.088 0.087 0.043 0.068 0.06...
# 1081  0.057 0.058 0.151 0.049 0.037 0.058 0.073 0.07...
# 1082  0.051 0.051 0.197 0.113 0.051 0.033 0.051 0.06...
# 1083  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...

# %%
#yesterday_str = (datetime.now() - timedelta(days=2)).strftime('%Y-%m-%d')
#df_isw_vect = df_isw_vect[df_isw_vect['date'] == yesterday_str]
df_isw_vect = df_isw_vect.tail(1)

# %%
df_isw_vect["date"]
# Out:
# 1083    2025-04-24
# Name: date, dtype: object

# %%
#df_isw_vect["date"] = pd.to_datetime(df_isw_vect["date"])
#df_isw_vect["date_tomorrow_datetime"] = df_isw_vect["date"] + datetime.timedelta(days=1)

# %%
#df_ready = df_weather_reg_al.merge(df_isw_vect, how="left", left_on="day_datetime", right_on="date_tomorrow_datetime")
df_isw_vect = pd.concat([df_isw_vect] * len(df_weather_reg_al), ignore_index=True)
df_ready = pd.concat([df_weather_reg_al.reset_index(drop=True), df_isw_vect.reset_index(drop=True)], axis=1)

# %%
df_ready.head()
# Out:
#   city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0     Вінниця, Україна   2025-05-05         1746392400         15.4
# 1     Вінниця, Україна   2025-05-06         1746478800         14.7
# 2     Вінниця, Україна   2025-05-06         1746478800         14.7
# 3     Вінниця, Україна   2025-05-06         1746478800         14.7
# 4     Вінниця, Україна   2025-05-06         1746478800         14.7
#
#    day_tempmin  day_temp  day_dew  day_humidity  day_precip  day_precipcover  \
# 0          9.7      12.2      9.2          82.2         5.5            45.83
# 1          8.3      11.2      7.8          79.9         5.3            45.83
# 2          8.3      11.2      7.8          79.9         5.3            45.83
# 3          8.3      11.2      7.8          79.9         5.3            45.83
# 4          8.3      11.2      7.8          79.9         5.3            45.83
#
#    ...  center_city_ua  center_city_en  region_alt region_id status  \
# 0  ...         Вінниця       Vinnytsia  Вінниччина         2      1
# 1  ...         Вінниця       Vinnytsia  Вінниччина         2      1
# 2  ...         Вінниця       Vinnytsia  Вінниччина         2      1
# 3  ...         Вінниця       Vinnytsia  Вінниччина         2      1
# 4  ...         Вінниця       Vinnytsia  Вінниччина         2      1
#
#          date                                            content  \
# 0  2025-04-24  russian offensive campaign assessment 2025 chr...
# 1  2025-04-24  russian offensive campaign assessment 2025 chr...
# 2  2025-04-24  russian offensive campaign assessment 2025 chr...
# 3  2025-04-24  russian offensive campaign assessment 2025 chr...
# 4  2025-04-24  russian offensive campaign assessment 2025 chr...
#
#                                        lemma_content  \
# 0  russian offensive campaign assessment 2025 chr...
# 1  russian offensive campaign assessment 2025 chr...
# 2  russian offensive campaign assessment 2025 chr...
# 3  russian offensive campaign assessment 2025 chr...
# 4  russian offensive campaign assessment 2025 chr...
#
#                                         stem_content  \
# 0  russian offens campaign assess 2025 christina ...
# 1  russian offens campaign assess 2025 christina ...
# 2  russian offens campaign assess 2025 christina ...
# 3  russian offens campaign assess 2025 christina ...
# 4  russian offens campaign assess 2025 christina ...
#
#                                             keywords
# 0  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 1  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 2  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 3  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 4  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
#
# [5 rows x 46 columns]

# %%
df_ready.columns
# Out:
# Index(['city_resolvedAddress', 'day_datetime', 'day_datetimeEpoch',
#        'day_tempmax', 'day_tempmin', 'day_temp', 'day_dew', 'day_humidity',
#        'day_precip', 'day_precipcover', 'day_solarradiation',
#        'day_solarenergy', 'day_uvindex', 'day_sunrise', 'day_sunset',
#        'day_moonphase', 'hour_datetime', 'hour_datetimeEpoch', 'hour_temp',
#        'hour_humidity', 'hour_dew', 'hour_precip', 'hour_precipprob',
#        'hour_snow', 'hour_snowdepth', 'hour_preciptype', 'hour_windgust',
#        'hour_windspeed', 'hour_winddir', 'hour_pressure', 'hour_visibility',
#        'hour_cloudcover', 'hour_uvindex', 'hour_conditions', 'city', 'region',
#        'center_city_ua', 'center_city_en', 'region_alt', 'region_id', 'status',
#        'date', 'content', 'lemma_content', 'stem_content', 'keywords'],
#       dtype='object')

# %%
df_ready
# Out:
#     city_resolvedAddress day_datetime  day_datetimeEpoch  day_tempmax  \
# 0       Вінниця, Україна   2025-05-05         1746392400         15.4
# 1       Вінниця, Україна   2025-05-06         1746478800         14.7
# 2       Вінниця, Україна   2025-05-06         1746478800         14.7
# 3       Вінниця, Україна   2025-05-06         1746478800         14.7
# 4       Вінниця, Україна   2025-05-06         1746478800         14.7
# ..                   ...          ...                ...          ...
# 571        Київ, Україна   2025-05-06         1746478800         13.3
# 572        Київ, Україна   2025-05-06         1746478800         13.3
# 573        Київ, Україна   2025-05-06         1746478800         13.3
# 574        Київ, Україна   2025-05-06         1746478800         13.3
# 575        Київ, Україна   2025-05-06         1746478800         13.3
#
#      day_tempmin  day_temp  day_dew  day_humidity  day_precip  \
# 0            9.7      12.2      9.2          82.2         5.5
# 1            8.3      11.2      7.8          79.9         5.3
# 2            8.3      11.2      7.8          79.9         5.3
# 3            8.3      11.2      7.8          79.9         5.3
# 4            8.3      11.2      7.8          79.9         5.3
# ..           ...       ...      ...           ...         ...
# 571          7.2      10.6      3.8          63.2         0.8
# 572          7.2      10.6      3.8          63.2         0.8
# 573          7.2      10.6      3.8          63.2         0.8
# 574          7.2      10.6      3.8          63.2         0.8
# 575          7.2      10.6      3.8          63.2         0.8
#
#      day_precipcover  ...  center_city_ua  center_city_en  region_alt  \
# 0              45.83  ...         Вінниця       Vinnytsia  Вінниччина
# 1              45.83  ...         Вінниця       Vinnytsia  Вінниччина
# 2              45.83  ...         Вінниця       Vinnytsia  Вінниччина
# 3              45.83  ...         Вінниця       Vinnytsia  Вінниччина
# 4              45.83  ...         Вінниця       Vinnytsia  Вінниччина
# ..               ...  ...             ...             ...         ...
# 571            16.67  ...            Київ            Kyiv    Київщина
# 572            16.67  ...            Київ            Kyiv    Київщина
# 573            16.67  ...            Київ            Kyiv    Київщина
# 574            16.67  ...            Київ            Kyiv    Київщина
# 575            16.67  ...            Київ            Kyiv    Київщина
#
#     region_id status        date  \
# 0           2      1  2025-04-24
# 1           2      1  2025-04-24
# 2           2      1  2025-04-24
# 3           2      1  2025-04-24
# 4           2      1  2025-04-24
# ..        ...    ...         ...
# 571         1      1  2025-04-24
# 572         1      1  2025-04-24
# 573         1      1  2025-04-24
# 574         1      1  2025-04-24
# 575         1      1  2025-04-24
#
#                                                content  \
# 0    russian offensive campaign assessment 2025 chr...
# 1    russian offensive campaign assessment 2025 chr...
# 2    russian offensive campaign assessment 2025 chr...
# 3    russian offensive campaign assessment 2025 chr...
# 4    russian offensive campaign assessment 2025 chr...
# ..                                                 ...
# 571  russian offensive campaign assessment 2025 chr...
# 572  russian offensive campaign assessment 2025 chr...
# 573  russian offensive campaign assessment 2025 chr...
# 574  russian offensive campaign assessment 2025 chr...
# 575  russian offensive campaign assessment 2025 chr...
#
#                                          lemma_content  \
# 0    russian offensive campaign assessment 2025 chr...
# 1    russian offensive campaign assessment 2025 chr...
# 2    russian offensive campaign assessment 2025 chr...
# 3    russian offensive campaign assessment 2025 chr...
# 4    russian offensive campaign assessment 2025 chr...
# ..                                                 ...
# 571  russian offensive campaign assessment 2025 chr...
# 572  russian offensive campaign assessment 2025 chr...
# 573  russian offensive campaign assessment 2025 chr...
# 574  russian offensive campaign assessment 2025 chr...
# 575  russian offensive campaign assessment 2025 chr...
#
#                                           stem_content  \
# 0    russian offens campaign assess 2025 christina ...
# 1    russian offens campaign assess 2025 christina ...
# 2    russian offens campaign assess 2025 christina ...
# 3    russian offens campaign assess 2025 christina ...
# 4    russian offens campaign assess 2025 christina ...
# ..                                                 ...
# 571  russian offens campaign assess 2025 christina ...
# 572  russian offens campaign assess 2025 christina ...
# 573  russian offens campaign assess 2025 christina ...
# 574  russian offens campaign assess 2025 christina ...
# 575  russian offens campaign assess 2025 christina ...
#
#                                               keywords
# 0    0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 1    0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 2    0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 3    0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 4    0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# ..                                                 ...
# 571  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 572  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 573  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 574  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
# 575  0.067 0.067 0.087 0.149 0.058 0.043 0.068 0.08...
#
# [576 rows x 46 columns]

# %%
df = df_ready.fillna(df_ready.median(numeric_only=True))
df['hour_preciptype'] = df['hour_preciptype'].astype(str)

# %%
df_encoded = pd.get_dummies(df, columns=['hour_preciptype'], prefix='hour_preciptype')

# %%
bool_columns = df_encoded.select_dtypes(include=['bool']).columns
df_encoded[bool_columns] = df_encoded[bool_columns].astype(int)

# %%
preciptype = [
    "hour_preciptype_['freezingrain']",
    "hour_preciptype_['ice']",
    "hour_preciptype_['rain', 'snow']",
    "hour_preciptype_['rain']",
    "hour_preciptype_['snow']"
]

for col in preciptype:
    if col not in df_encoded.columns:
        df_encoded[col] = 0
other_cols = [c for c in df_encoded.columns if c not in preciptype]
df_encoded = df_encoded[other_cols + preciptype]

# %%
todrop = [
    'city_resolvedAddress',
    'day_datetime', 
    'city', 
    'region',
    'center_city_ua', 
    'center_city_en', 
    'region_alt', 
    'date', 
    'content', 
    'lemma_content', 
    'stem_content']

# %%
df_encoded = df_encoded.drop(todrop, axis=1)

# %%
df_encoded.columns
# Out:
# Index(['day_datetimeEpoch', 'day_tempmax', 'day_tempmin', 'day_temp',
#        'day_dew', 'day_humidity', 'day_precip', 'day_precipcover',
#        'day_solarradiation', 'day_solarenergy', 'day_uvindex', 'day_sunrise',
#        'day_sunset', 'day_moonphase', 'hour_datetime', 'hour_datetimeEpoch',
#        'hour_temp', 'hour_humidity', 'hour_dew', 'hour_precip',
#        'hour_precipprob', 'hour_snow', 'hour_snowdepth', 'hour_windgust',
#        'hour_windspeed', 'hour_winddir', 'hour_pressure', 'hour_visibility',
#        'hour_cloudcover', 'hour_uvindex', 'hour_conditions', 'region_id',
#        'status', 'keywords', 'hour_preciptype_None',
#        'hour_preciptype_['freezingrain']', 'hour_preciptype_['ice']',
#        'hour_preciptype_['rain', 'snow']', 'hour_preciptype_['rain']',
#        'hour_preciptype_['snow']'],
#       dtype='object')

# %%
df_encoded.shape
# Out:
# (576, 40)

# %%
temp_df = df_encoded['keywords'].str.split(expand=True)
temp_df = temp_df.astype('float64')
df_encoded_v2 = pd.concat([df_encoded.drop('keywords', axis=1), temp_df], axis=1)

# %%
unique_values = sorted(df['hour_conditions'].astype(str).unique())
mapping = {val: idx for idx, val in enumerate(unique_values)}
df_encoded_v2['hour_conditions'] = df['hour_conditions'].astype(str).map(mapping)

# %%
df_encoded_v2['hour_datetime'] = pd.to_datetime(df_encoded_v2['hour_datetime'], format='%H:%M:%S')
df_encoded_v2['day_sunrise'] = pd.to_datetime(df_encoded_v2['day_sunrise'], format='%H:%M:%S')
df_encoded_v2['day_sunset'] = pd.to_datetime(df_encoded_v2['day_sunset'], format='%H:%M:%S')
df_encoded_v2['hour_datetime'] = (df_encoded_v2['hour_datetime'].dt.hour * 3600 +
                                  df_encoded_v2['hour_datetime'].dt.minute * 60 +
                                  df_encoded_v2['hour_datetime'].dt.second) / 86400

df_encoded_v2['day_sunrise'] = (df_encoded_v2['day_sunrise'].dt.hour * 3600 +
                                df_encoded_v2['day_sunrise'].dt.minute * 60 +
                                df_encoded_v2['day_sunrise'].dt.second) / 86400

df_encoded_v2['day_sunset'] = (df_encoded_v2['day_sunset'].dt.hour * 3600 +
                               df_encoded_v2['day_sunset'].dt.minute * 60 +
                               df_encoded_v2['day_sunset'].dt.second) / 86400

# %%
df_encoded_v2
# Out:
#      day_datetimeEpoch  day_tempmax  day_tempmin  day_temp  day_dew  \
# 0           1746392400         15.4          9.7      12.2      9.2
# 1           1746478800         14.7          8.3      11.2      7.8
# 2           1746478800         14.7          8.3      11.2      7.8
# 3           1746478800         14.7          8.3      11.2      7.8
# 4           1746478800         14.7          8.3      11.2      7.8
# ..                 ...          ...          ...       ...      ...
# 571         1746478800         13.3          7.2      10.6      3.8
# 572         1746478800         13.3          7.2      10.6      3.8
# 573         1746478800         13.3          7.2      10.6      3.8
# 574         1746478800         13.3          7.2      10.6      3.8
# 575         1746478800         13.3          7.2      10.6      3.8
#
#      day_humidity  day_precip  day_precipcover  day_solarradiation  \
# 0            82.2         5.5            45.83                90.0
# 1            79.9         5.3            45.83                20.0
# 2            79.9         5.3            45.83                20.0
# 3            79.9         5.3            45.83                20.0
# 4            79.9         5.3            45.83                20.0
# ..            ...         ...              ...                 ...
# 571          63.2         0.8            16.67                92.1
# 572          63.2         0.8            16.67                92.1
# 573          63.2         0.8            16.67                92.1
# 574          63.2         0.8            16.67                92.1
# 575          63.2         0.8            16.67                92.1
#
#      day_solarenergy  ...    990    991    992    993    994    995    996  \
# 0                7.8  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 1                1.7  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 2                1.7  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 3                1.7  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 4                1.7  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# ..               ...  ...    ...    ...    ...    ...    ...    ...    ...
# 571              8.0  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 572              8.0  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 573              8.0  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 574              8.0  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
# 575              8.0  ...  0.036  0.043  0.081  0.257  0.082  0.064  0.079
#
#        997    998    999
# 0    0.034  0.181  0.072
# 1    0.034  0.181  0.072
# 2    0.034  0.181  0.072
# 3    0.034  0.181  0.072
# 4    0.034  0.181  0.072
# ..     ...    ...    ...
# 571  0.034  0.181  0.072
# 572  0.034  0.181  0.072
# 573  0.034  0.181  0.072
# 574  0.034  0.181  0.072
# 575  0.034  0.181  0.072
#
# [576 rows x 1039 columns]

# %%
df_temp = pd.read_parquet("../../data/all_data_preprocessed/all_merged_tfidf.parquet", engine="pyarrow", columns=['event_all_region', 'region_id', 'hour_datetimeEpoch'])

# %%
df_temp['timestamp'] = pd.to_datetime(df_temp['hour_datetimeEpoch'], unit='s')
df_temp['date'] = df_temp['timestamp'].dt.date
last_date = df_temp['date'].max()
df_temp = df_temp[df_temp['date'] == last_date]

# %%
df_temp
# Out:
#         event_all_region  region_id  hour_datetimeEpoch           timestamp  \
# 25922                1.0          1          1740787200 2025-03-01 00:00:00
# 25923                1.0          1          1740790800 2025-03-01 01:00:00
# 25924                1.0          1          1740794400 2025-03-01 02:00:00
# 25925                1.0          1          1740798000 2025-03-01 03:00:00
# 25926                1.0          1          1740801600 2025-03-01 04:00:00
# ...                  ...        ...                 ...                 ...
# 622651               0.0         25          1740848400 2025-03-01 17:00:00
# 622652               0.0         25          1740852000 2025-03-01 18:00:00
# 622653               0.0         25          1740855600 2025-03-01 19:00:00
# 622654               0.0         25          1740859200 2025-03-01 20:00:00
# 622655               1.0         25          1740862800 2025-03-01 21:00:00
#
#               date
# 25922   2025-03-01
# 25923   2025-03-01
# 25924   2025-03-01
# 25925   2025-03-01
# 25926   2025-03-01
# ...            ...
# 622651  2025-03-01
# 622652  2025-03-01
# 622653  2025-03-01
# 622654  2025-03-01
# 622655  2025-03-01
#
# [528 rows x 5 columns]

# %%
df_encoded_v2['timestamp'] = pd.to_datetime(df_encoded_v2['hour_datetimeEpoch'], unit='s')
df_encoded_v2['timestamp'] = pd.to_datetime(df_encoded_v2['timestamp'])
df_encoded_v2 = df_encoded_v2.set_index(pd.DatetimeIndex(df_encoded_v2['timestamp']))
df_temp = df_temp.set_index(pd.DatetimeIndex(df_temp['timestamp']))

# %%
hourly_has_event = df_temp.groupby('region_id')['event_all_region'].resample('h').sum().gt(0).astype(int)
hours_with_events_per_day = hourly_has_event.groupby('region_id').resample('D', level=1).sum()

hours_with_events_per_day = hours_with_events_per_day.reset_index()
hours_with_events_per_day.rename(columns={'event_all_region': 'event_lastDay_region'}, inplace=True)

df_encoded_v2['date'] = df_encoded_v2['timestamp'].dt.strftime('%Y-%m-%d')
hours_with_events_per_day['date'] = hours_with_events_per_day['timestamp'].dt.strftime('%Y-%m-%d')

df_encoded_v2
# Out:
#                      day_datetimeEpoch  day_tempmax  day_tempmin  day_temp  \
# timestamp
# 2025-05-05 20:00:00         1746392400         15.4          9.7      12.2
# 2025-05-05 21:00:00         1746478800         14.7          8.3      11.2
# 2025-05-05 22:00:00         1746478800         14.7          8.3      11.2
# 2025-05-05 23:00:00         1746478800         14.7          8.3      11.2
# 2025-05-06 00:00:00         1746478800         14.7          8.3      11.2
# ...                                ...          ...          ...       ...
# 2025-05-06 15:00:00         1746478800         13.3          7.2      10.6
# 2025-05-06 16:00:00         1746478800         13.3          7.2      10.6
# 2025-05-06 17:00:00         1746478800         13.3          7.2      10.6
# 2025-05-06 18:00:00         1746478800         13.3          7.2      10.6
# 2025-05-06 19:00:00         1746478800         13.3          7.2      10.6
#
#                      day_dew  day_humidity  day_precip  day_precipcover  \
# timestamp
# 2025-05-05 20:00:00      9.2          82.2         5.5            45.83
# 2025-05-05 21:00:00      7.8          79.9         5.3            45.83
# 2025-05-05 22:00:00      7.8          79.9         5.3            45.83
# 2025-05-05 23:00:00      7.8          79.9         5.3            45.83
# 2025-05-06 00:00:00      7.8          79.9         5.3            45.83
# ...                      ...           ...         ...              ...
# 2025-05-06 15:00:00      3.8          63.2         0.8            16.67
# 2025-05-06 16:00:00      3.8          63.2         0.8            16.67
# 2025-05-06 17:00:00      3.8          63.2         0.8            16.67
# 2025-05-06 18:00:00      3.8          63.2         0.8            16.67
# 2025-05-06 19:00:00      3.8          63.2         0.8            16.67
#
#                      day_solarradiation  day_solarenergy  ...    992    993  \
# timestamp                                                 ...
# 2025-05-05 20:00:00                90.0              7.8  ...  0.081  0.257
# 2025-05-05 21:00:00                20.0              1.7  ...  0.081  0.257
# 2025-05-05 22:00:00                20.0              1.7  ...  0.081  0.257
# 2025-05-05 23:00:00                20.0              1.7  ...  0.081  0.257
# 2025-05-06 00:00:00                20.0              1.7  ...  0.081  0.257
# ...                                 ...              ...  ...    ...    ...
# 2025-05-06 15:00:00                92.1              8.0  ...  0.081  0.257
# 2025-05-06 16:00:00                92.1              8.0  ...  0.081  0.257
# 2025-05-06 17:00:00                92.1              8.0  ...  0.081  0.257
# 2025-05-06 18:00:00                92.1              8.0  ...  0.081  0.257
# 2025-05-06 19:00:00                92.1              8.0  ...  0.081  0.257
#
#                        994    995    996    997    998    999  \
# timestamp
# 2025-05-05 20:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-05 21:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-05 22:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-05 23:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-06 00:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# ...                    ...    ...    ...    ...    ...    ...
# 2025-05-06 15:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-06 16:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-06 17:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-06 18:00:00  0.082  0.064  0.079  0.034  0.181  0.072
# 2025-05-06 19:00:00  0.082  0.064  0.079  0.034  0.181  0.072
#
#                               timestamp        date
# timestamp
# 2025-05-05 20:00:00 2025-05-05 20:00:00  2025-05-05
# 2025-05-05 21:00:00 2025-05-05 21:00:00  2025-05-05
# 2025-05-05 22:00:00 2025-05-05 22:00:00  2025-05-05
# 2025-05-05 23:00:00 2025-05-05 23:00:00  2025-05-05
# 2025-05-06 00:00:00 2025-05-06 00:00:00  2025-05-06
# ...                                 ...         ...
# 2025-05-06 15:00:00 2025-05-06 15:00:00  2025-05-06
# 2025-05-06 16:00:00 2025-05-06 16:00:00  2025-05-06
# 2025-05-06 17:00:00 2025-05-06 17:00:00  2025-05-06
# 2025-05-06 18:00:00 2025-05-06 18:00:00  2025-05-06
# 2025-05-06 19:00:00 2025-05-06 19:00:00  2025-05-06
#
# [576 rows x 1041 columns]

# %%
df_encoded_v2.drop('timestamp', axis=1, inplace=True)
df_encoded_v2.reset_index(inplace=True)
df_encoded_v2 = df_encoded_v2.sort_values('timestamp')
hours_with_events_per_day = hours_with_events_per_day.sort_values('timestamp')

# %%
df_encoded_v2 = pd.merge_asof(
    df_encoded_v2,
    hours_with_events_per_day[['timestamp', 'region_id', 'event_lastDay_region']],
    on='timestamp',
    by='region_id',
    direction='backward'
)

# %%
df_encoded_v2
# Out:
#               timestamp  day_datetimeEpoch  day_tempmax  day_tempmin  \
# 0   2025-05-05 20:00:00         1746392400         15.4          9.7
# 1   2025-05-05 20:00:00         1746392400         23.9          9.7
# 2   2025-05-05 20:00:00         1746392400         15.6         10.7
# 3   2025-05-05 20:00:00         1746392400         14.0          9.0
# 4   2025-05-05 20:00:00         1746392400         23.8         10.9
# ..                  ...                ...          ...          ...
# 571 2025-05-06 19:00:00         1746478800         21.9         11.5
# 572 2025-05-06 19:00:00         1746478800         11.0          7.8
# 573 2025-05-06 19:00:00         1746478800         13.4         11.0
# 574 2025-05-06 19:00:00         1746478800          9.8          6.7
# 575 2025-05-06 19:00:00         1746478800         13.3          7.2
#
#      day_temp  day_dew  day_humidity  day_precip  day_precipcover  \
# 0        12.2      9.2          82.2         5.5            45.83
# 1        17.1      8.2          58.5         0.0             0.00
# 2        12.8      7.7          71.7         1.9            41.67
# 3        11.9      5.5          65.3         2.3            45.83
# 4        17.6      8.9          59.9         0.0             0.00
# ..        ...      ...           ...         ...              ...
# 571      16.0      9.5          67.7         0.3            12.50
# 572       9.4      6.7          83.4         9.1            45.83
# 573      12.4      9.2          81.2         5.9            29.17
# 574       8.4      5.5          82.1         1.3            37.50
# 575      10.6      3.8          63.2         0.8            16.67
#
#      day_solarradiation  ...    992    993    994    995    996    997    998  \
# 0                  90.0  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 1                 187.3  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 2                  29.3  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 3                  39.7  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 4                 282.3  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# ..                  ...  ...    ...    ...    ...    ...    ...    ...    ...
# 571               209.2  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 572                26.7  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 573                22.5  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 574                17.8  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
# 575                92.1  ...  0.081  0.257  0.082  0.064  0.079  0.034  0.181
#
#        999        date  event_lastDay_region
# 0    0.072  2025-05-05                     4
# 1    0.072  2025-05-05                    22
# 2    0.072  2025-05-05                     4
# 3    0.072  2025-05-05                     0
# 4    0.072  2025-05-05                    17
# ..     ...         ...                   ...
# 571  0.072  2025-05-06                    10
# 572  0.072  2025-05-06                     0
# 573  0.072  2025-05-06                     3
# 574  0.072  2025-05-06                     0
# 575  0.072  2025-05-06                     5
#
# [576 rows x 1042 columns]

# %%
class UkrainianECBHolidays(holidays.HolidayBase):
    def __init__(self, years=None, **kwargs):
        self.country = "UA"
        super().__init__(years=years, **kwargs)

    def _populate(self, year):
        self[date(year, 1, 1)] = "New Year's Day"
        self[date(year, 1, 7)] = "Orthodox Christmas"
        self[date(year, 3, 8)] = "International Women's Day"
        self[date(year, 5, 1)] = "Labour Day"
        self[date(year, 5, 8)] = "Day of Remembrance and Reconciliation"
        self[date(year, 5, 9)] = "Victory Day"
        self[date(year, 6, 28)] = "Constitution Day of Ukraine"
        self[date(year, 8, 24)] = "Independence Day of Ukraine"
        self[date(year, 12, 25)] = "Christmas (Western)"


class RussianECBHolidays(holidays.HolidayBase):
    def __init__(self, years=None, **kwargs):
        self.country = "RU"
        super().__init__(years=years, **kwargs)

    def _populate(self, year):
        self[date(year, 1, 1)] = "New Year's Day (Russia)"
        self[date(year, 1, 7)] = "Orthodox Christmas (Russia)"
        self[date(year, 2, 23)] = "Defender of the Fatherland Day (Russia)"
        self[date(year, 3, 8)] = "International Women's Day (Russia)"
        self[date(year, 5, 1)] = "Spring and Labor Day (Russia)"
        self[date(year, 5, 9)] = "Victory Day (Russia)"
        self[date(year, 6, 12)] = "Russia Day"
        self[date(year, 11, 4)] = "Unity Day (Russia)"

# %%
ua_holidays = UkrainianECBHolidays(years=range(2020, 2032))
ru_holidays = RussianECBHolidays(years=range(2020, 2032))

# %%
df_encoded_v2['ru_holiday'] = df_encoded_v2['date'].apply(lambda x: 1 if x in ru_holidays else 0)
df_encoded_v2['ua_holiday'] = df_encoded_v2['date'].apply(lambda x: 1 if x in ua_holidays else 0)

# %%
df_encoded_v2.drop('date', axis=1, inplace=True)

# %%
df_encoded_v2.drop('timestamp', axis=1, inplace=True)

# %%
df_encoded_v2
# Out:
#      day_datetimeEpoch  day_tempmax  day_tempmin  day_temp  day_dew  \
# 0           1746392400         15.4          9.7      12.2      9.2
# 1           1746392400         23.9          9.7      17.1      8.2
# 2           1746392400         15.6         10.7      12.8      7.7
# 3           1746392400         14.0          9.0      11.9      5.5
# 4           1746392400         23.8         10.9      17.6      8.9
# ..                 ...          ...          ...       ...      ...
# 571         1746478800         21.9         11.5      16.0      9.5
# 572         1746478800         11.0          7.8       9.4      6.7
# 573         1746478800         13.4         11.0      12.4      9.2
# 574         1746478800          9.8          6.7       8.4      5.5
# 575         1746478800         13.3          7.2      10.6      3.8
#
#      day_humidity  day_precip  day_precipcover  day_solarradiation  \
# 0            82.2         5.5            45.83                90.0
# 1            58.5         0.0             0.00               187.3
# 2            71.7         1.9            41.67                29.3
# 3            65.3         2.3            45.83                39.7
# 4            59.9         0.0             0.00               282.3
# ..            ...         ...              ...                 ...
# 571          67.7         0.3            12.50               209.2
# 572          83.4         9.1            45.83                26.7
# 573          81.2         5.9            29.17                22.5
# 574          82.1         1.3            37.50                17.8
# 575          63.2         0.8            16.67                92.1
#
#      day_solarenergy  ...    993    994    995    996    997    998    999  \
# 0                7.8  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 1               16.4  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 2                2.5  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 3                3.3  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 4               24.3  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# ..               ...  ...    ...    ...    ...    ...    ...    ...    ...
# 571             17.9  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 572              2.1  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 573              1.9  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 574              1.6  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
# 575              8.0  ...  0.257  0.082  0.064  0.079  0.034  0.181  0.072
#
#      event_lastDay_region  ru_holiday  ua_holiday
# 0                       4           0           0
# 1                      22           0           0
# 2                       4           0           0
# 3                       0           0           0
# 4                      17           0           0
# ..                    ...         ...         ...
# 571                    10           0           0
# 572                     0           0           0
# 573                     3           0           0
# 574                     0           0           0
# 575                     5           0           0
#
# [576 rows x 1042 columns]

# %%
col_data = df_encoded_v2.pop("status")
insert_at = df_encoded_v2.columns.get_loc("event_lastDay_region") + 1
df_encoded_v2.insert(insert_at, "status", col_data)

# %%
col_data = df_encoded_v2.pop("region_id")
insert_at = df_encoded_v2.columns.get_loc('day_datetimeEpoch')
df_encoded_v2.insert(insert_at, "region_id", col_data)

# %%
df_encoded_v2.drop(["hour_preciptype_None"], axis=1, inplace=True)

# %%
#df_encoded_v2.drop("event_lastDay_region", axis=1, inplace=True)

# %%
data_dir = '../predict_data/everyhour_predict'
os.makedirs(data_dir, exist_ok=True)

# %%
csv_path = os.path.join(data_dir, 'test.csv')
df_encoded_v2.to_csv(csv_path, sep=';', index=False)

# %%
df_encoded_v2['event_lastDay_region']
# Out:
# 0       4
# 1      22
# 2       4
# 3       0
# 4      17
#        ..
# 571    10
# 572     0
# 573     3
# 574     0
# 575     5
# Name: event_lastDay_region, Length: 576, dtype: int64
